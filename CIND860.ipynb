# %%
#Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Data
df=pd.read_csv("C:\\Users\\carol\\Desktop\\School\\Ryerson\\CIND860\\insurance_claims.csv")

# %%
#Exploring the Data

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
df.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# ...

# %%
for i in df.columns:
    plt.hist(df[i])
    plt.title(i)
    plt.show()
# Out:
# C:\Users\carol\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6623: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# C:\Users\carol\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6624: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 for i in df.columns:
# ----> 2     plt.hist(df[i])
#       3     plt.title(i)
#       4     plt.show()
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2685, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2679 @_copy_docstring_and_deprecators(Axes.hist)
#    2680 def hist(
#    2681         x, bins=None, range=None, density=False, weights=None,
# ...

# %%
df.corr()
# Out:
#                              months_as_customer       age  policy_number  \
# months_as_customer                     1.000000  0.922098       0.057555
# age                                    0.922098  1.000000       0.059413
# policy_number                          0.057555  0.059413       1.000000
# policy_deductable                      0.026807  0.029188      -0.006738
# policy_annual_premium                  0.005018  0.014404       0.022566
# umbrella_limit                         0.015498  0.018126       0.008968
# insured_zip                            0.017895  0.025604       0.007083
# capital-gains                          0.006399 -0.007075       0.009802
# capital-loss                           0.020209  0.007368      -0.005669
# incident_hour_of_the_day               0.070639  0.087161       0.000113
# number_of_vehicles_involved            0.014736  0.022102       0.013432
# bodily_injuries                       -0.010162 -0.015679      -0.004558
# ...

# %%
corr=df.corr()

# %%
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
#It would be interesting to see what the correlation is for fraud reported.
df['fraud_reported'] = df['fraud_reported'].map({'Y': 1, 'N': 0})

# %%
df.corr()
# Out:
#                              months_as_customer       age  policy_number  \
# months_as_customer                     1.000000  0.922098       0.057555
# age                                    0.922098  1.000000       0.059413
# policy_number                          0.057555  0.059413       1.000000
# policy_deductable                      0.026807  0.029188      -0.006738
# policy_annual_premium                  0.005018  0.014404       0.022566
# umbrella_limit                         0.015498  0.018126       0.008968
# insured_zip                            0.017895  0.025604       0.007083
# capital-gains                          0.006399 -0.007075       0.009802
# capital-loss                           0.020209  0.007368      -0.005669
# incident_hour_of_the_day               0.070639  0.087161       0.000113
# number_of_vehicles_involved            0.014736  0.022102       0.013432
# bodily_injuries                       -0.010162 -0.015679      -0.004558
# ...

# %%
corr=df.corr()
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
df.fraud_reported.value_counts()
# Out:
# 0    753
# 1    247
# Name: fraud_reported, dtype: int64

# %%
#seems there is a very minor correlation with "total claim amount", "injury claim", "property claim", "vehicle claim".

# %%
#CLEANING THE DATA

# %%
#Remove unnecessary columns.
# policy_number --> could be used to identify customer. Likely randomly provided so should not contain valuable information.
# if policy number assigned with purpose, that information is not available and therefore would not be helpful.
# incident location
#_c39 --> seems like a junk column - remove it
df = df.drop('_c39', axis=1)
df = df.drop("policy_number", axis=1)
df = df.drop("incident_location", axis=1)
df.head()

# %%
df.info()

# %%
for i in df.columns:
    unique_values = df[i].unique()
    print(f"Unique values in column '{i}': {unique_values}")

# %%
#collision type has "?"
#property damage has "?"
#police report available has "?"
